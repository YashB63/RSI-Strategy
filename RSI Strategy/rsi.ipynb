# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %%
# tickers for all S&P 500 Companies

tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# %%
tickers
# Out:
#     Symbol              Security             GICS Sector
# 0      MMM                    3M             Industrials  \
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04  \
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# ...

# %%
# transform to list
tickers = tickers.Symbol.to_list()

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BG',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
# ...

# %%
tickers = [i.replace('.','-') for i in tickers]

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK-B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF-B',
#  'BG',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
# ...

# %%
tickers.pop(489)
# Out:
# 'WRK'

# %%
tickers.pop(474)
# Out:
# 'VTRS'

# %%
def rsi_calculate(asset):
    df = yf.download(asset,start='2013-1-1')# let's go 10 years back
    df['Moving_Averages_200'] = df['Adj Close'].rolling(window=200).mean()
    df['Price_Change'] = df['Adj Close'].pct_change()
    df['Upmove'] = df['Price_Change'].apply(lambda x: x if x>0 else 0)
    df['Downmove'] = df['Price_Change'].apply(lambda x: abs(x) if x<0 else 0)
    df['Average_Up'] = df['Upmove'].ewm(span=19).mean()
    df['Average_Down'] = df['Downmove'].ewm(span=19).mean()
    df = df.dropna()
    df['RS'] = df['Average_Up']/df['Average_Down']
    df['RSI'] = df['RS'].apply(lambda x: 100-(100/(x+1)))
    df.loc[(df['Adj Close'] > df['Moving_Averages_200']) & (df['RSI']<30), 'Buy'] = 'Yes'
    df.loc[(df['Adj Close'] > df['Moving_Averages_200']) | (df['RSI']>30), 'Buy'] = 'No'
    return df

# %%
rsi_calculate(tickers[0])#after writing moving averages
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2013-01-02   94.190002   94.790001   93.959999   94.779999   68.910500  \
# 2013-01-03   94.339996   94.930000   94.129997   94.669998   68.830544
# 2013-01-04   94.790001   95.480003   94.540001   95.370003   69.339462
# 2013-01-07   95.019997   95.730003   94.760002   95.489998   69.426712
# 2013-01-08   95.169998   95.750000   95.099998   95.500000   69.433990
# ...                ...         ...         ...         ...         ...
# 2023-06-13  101.260002  103.139999  100.839996  102.739998  102.739998
# 2023-06-14  103.160004  103.669998  101.169998  101.949997  101.949997
# 2023-06-15  101.900002  104.089996  101.620003  103.809998  103.809998
# 2023-06-16  104.250000  104.889999  103.169998  104.540001  104.540001
# 2023-06-20  102.779999  102.930000  101.074997  102.299004  102.299004
#
#              Volume
# Date
# ...

# %%
rsi_calculate(tickers[0])#after writing complete function
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2013-10-16  120.860001  120.940002  120.139999  120.940002   89.469994  \
# 2013-10-17  120.739998  122.870003  120.709999  122.620003   90.712845
# 2013-10-18  122.870003  123.449997  122.400002  122.839996   90.875587
# 2013-10-21  122.790001  123.309998  122.680000  123.250000   91.178902
# 2013-10-22  123.360001  124.320000  123.279999  123.800003   91.585762
# ...                ...         ...         ...         ...         ...
# 2023-06-13  101.260002  103.139999  100.839996  102.739998  102.739998
# 2023-06-14  103.160004  103.669998  101.169998  101.949997  101.949997
# 2023-06-15  101.900002  104.089996  101.620003  103.809998  103.809998
# 2023-06-16  104.250000  104.889999  103.169998  104.540001  104.540001
# 2023-06-20  102.779999  102.930000  101.074997  102.430000  102.430000
#
# ...

# %%
def getSignals(df):
    Buying_Dates = []
    Selling_Dates = []
    
    for i in range(len(df)):
        if "Yes" in df['Buy'].iloc[i]:#iloc to check for the row value after iterating every single row
            #append row name to buying dates
            Buying_Dates.append(df.iloc[i+1].name)#+1 as we want to buy on the next day
            #Now more tricky one is to define the selling date as we have to account for RSI not exceeding 40 over th next 10 trading days
            for j in range(1,11):
                if df['RSI'].iloc[i+j]>40:
                    Selling_Dates.append(df.iloc[i+j+1].name)
                    break
                elif j==10:
                    Selling_Dates.append(df.iloc[i+j+1].name)
    
    return Buying_Dates,Selling_Dates

# %%
frame = rsi_calculate(tickers[0])
buy, sell = getSignals(frame)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 frame = rsi_calculate(tickers[0])
# ----> 2 buy, sell = getSignals(frame)
#
# Cell In[25], line 6, in getSignals(df)
#       3 Selling_Dates = []
#       5 for i in range(len(df)):
# ----> 6     if "Yes" in df['Buy'].iloc[i]:#iloc to check for the row value after iterating every single row
#       7         #append row name to buying dates
#       8         Buying_Dates.append(df.iloc[i+1].name)#+1 as we want to buy on the next day
#       9         #Now more tricky one is to define the selling date as we have to account for RSI not exceeding 40 over th next 10 trading days
#
# TypeError: argument of type 'float' is not iterable
